# %%
# ============================================================
# AIDev Dataset – Inspect column names for all tables
# ============================================================
import pandas as pd

# ------------------------------------------------------------
# 1. Load pull requests table
# ------------------------------------------------------------
print("=== Loading all_pull_request.parquet ===")
pulls = pd.read_parquet("hf://datasets/hao-li/AIDev/all_pull_request.parquet")
print("Pull Request columns:")
print(pulls.columns.tolist())
print("\nNumber of rows:", len(pulls))
print("------------------------------------------------------\n")


# ------------------------------------------------------------
# 2. Load repository table
# ------------------------------------------------------------
print("=== Loading all_repository.parquet ===")
repos = pd.read_parquet("hf://datasets/hao-li/AIDev/all_repository.parquet")
print("Repository columns:")
print(repos.columns.tolist())
print("\nNumber of rows:", len(repos))
print("------------------------------------------------------\n")


# ------------------------------------------------------------
# 3. Load user table
# ------------------------------------------------------------
print("=== Loading all_user.parquet ===")
users = pd.read_parquet("hf://datasets/hao-li/AIDev/all_user.parquet")
print("User columns:")
print(users.columns.tolist())
print("\nNumber of rows:", len(users))
print("------------------------------------------------------\n")


# ------------------------------------------------------------
# Summary
# ------------------------------------------------------------
print("Done. Copy the three column lists and send them to ChatGPT.")
# Out:
# Running cells with 'dqn-env (Python 3.10.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/miguel/Escritorio/UPC/erasmus/RL/Assignments/3/simple-dqn-release/dqn-env/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# !pip3 install ipykernel
